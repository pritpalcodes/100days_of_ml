# %% [markdown]
# ### Normalisation
# Normalization is a technique often applied as part of data preparation for machine learning. The goal of normalization is to change the values of numeric columns in the dataset to use a common scale, without distorting differences in the ranges of values or losing information.<br>
#
# #### Types of Normalisation
# - MinMax Scaling
# - Mean Normalisation
# - Max Absolute Scaling
# - Robust scaling
#
#
# #### MinMax Scaling
# ![image.png](attachment:image.png)
# The range of the MinMax will always lie between [0,1]
#
# ##### Gerometrical distribution:
# Nothing is being changed, just being squished betweem 0-1
# ![image-2.png](attachment:image-2.png)
# if the data is 2-D then it is being squished to a rectangle...agar 3-D  h data to it is being squished into, a Cube or something.<br>
#
# There is just one problem with min max scaling and that is, the impact of the outlier is also squished.

# %% [markdown]
# ### Mean Normalisation
# ![image.png](attachment:image.png)
# No class in scikit learn, used where we have centered data

# %% [markdown]
# ### Max Scaling
# used where there is sparse data
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Robust Scaling
# ![image.png](attachment:image.png)
# used wehre there are a lot of outliers, it is robust

# %% [markdown]
# ## Normalisation vs Standardisation
# - Is feature scaling required?
# -
