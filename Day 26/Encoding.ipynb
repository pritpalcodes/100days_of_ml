# %% [markdown]
# ![image.png](attachment:image.png)
#
# ###  Handling Categorical Data
# Some algorithms can not handle the categorical data. So for that we have to convert the catogerical daata into the numerical data. For which we use the following kinds of encoding techniques.
#
# #### Ordinal Encoding!
#     give the priority to the classes, and the 'ordinal encoding' library of the scikit learn will handle this shit!
# #### Label Encoding!
#
# #### One Hot Encoding!
#     applied on nominal data
